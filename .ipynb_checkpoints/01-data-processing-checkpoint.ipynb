# %%
import json
import pandas as pd
import numpy as np
import seaborn as sns

# %% [markdown]
# ### Prepare dataset

# %%
def prepare_dataset(path, include_oos=False):
    with open(path, "r") as f:
        data = json.loads(f.read())
    
    data_formatted = {"datatype": [], "query": [], "intent": []}
    for datatype, queries in data.items():
        for query_intent in queries:
            query, intent = query_intent
            if (intent != "oos") or include_oos:
                data_formatted["datatype"] += [datatype]
                data_formatted["query"] += [query]
                data_formatted["intent"] += [intent]
                
    df = pd.DataFrame(data_formatted)
    
    intents = df.intent.unique()
    intents_dict = dict((intent, i) for i, intent in enumerate(intents))
    df["intent_idx"] = df.intent.apply(lambda x: intents_dict[x])
    
    return df, intents_dict

# %%
path = "oos-eval/data/data_full.json"
df, intents_dict = prepare_dataset(path)

# %% [markdown]
# ### Summary of datasets

# %%
(df
 .datatype
 .value_counts()
 .to_frame()
)
# Out:
#        datatype
# train     15000
# test       4500
# val        3000

# %% [markdown]
# ### There are 150 unique intents and each intent as 150 records
# (100 train + 20 valid + 30 test)

# %%
(df
 .intent
 .value_counts()
 .to_frame()
)
# Out:
#                   intent
# order_status         150
# gas                  150
# repeat               150
# cancel               150
# reset_settings       150
# ...                  ...
# meeting_schedule     150
# mpg                  150
# calculator           150
# traffic              150
# bill_due             150
#
# [150 rows x 1 columns]

# %% [markdown]
# ### All intents

# %%
pd.DataFrame(df.intent.unique().reshape((30, 5)))
# Out:
#                         0                        1                     2  \
# 0               translate                 transfer                 timer
# 1        insurance_change               find_phone          travel_alert
# 2                fun_fact          change_language                payday
# 3      application_status            flight_status             flip_coin
# 4    shopping_list_update       what_can_i_ask_you                 maybe
# 5                 balance      confirm_reservation        freeze_account
# 6                distance                user_name              timezone
# 7   restaurant_suggestion          rewards_balance              pay_bill
# 8            credit_score                 new_card          lost_luggage
# 9         oil_change_when                      yes     travel_suggestion
# 10               reminder             change_speed         tire_pressure
# 11         nutrition_info                 calendar                  uber
# 12               carry_on                 pto_used  schedule_maintenance
# 13              thank_you                roll_dice             food_last
# 14       report_lost_card  ingredient_substitution             make_call
# 15          change_accent                       w2              bill_due
# 16     restaurant_reviews                  routing      do_you_have_pets
# 17              plug_type              tire_change         exchange_rate
# 18    who_do_you_work_for             credit_limit              how_busy
# 19             pin_change                  goodbye       account_blocked
# 20       last_maintenance         meeting_schedule      ingredients_list
# 21             smart_home               book_hotel      current_location
# 22            min_payment             whisper_mode                cancel
# 23            pto_balance               directions              spelling
# 24      what_is_your_name           direct_deposit         interest_rate
# 25            book_flight            shopping_list                  text
# 26         redeem_rewards               play_music       calendar_update
# 27        expiration_date          update_playlist    cancel_reservation
# 28        how_old_are_you               car_rental            jump_start
# 29                 income                    order               traffic
#
#                             3                       4
# 0                  definition         meaning_of_life
# 1                 pto_request    improve_credit_score
# 2   replacement_card_duration                    time
# 3            change_user_name      where_are_you_from
# 4              oil_change_how  restaurant_reservation
# 5               rollover_401k            who_made_you
# 6                   next_song            transactions
# 7            spending_history      pto_request_status
# 8                      repeat                     mpg
# 9                   insurance        todo_list_update
# 10                         no                     apr
# 11                 calculator                    date
# 12        travel_notification             sync_device
# 13                  cook_time         reminder_update
# 14                      alarm               todo_list
# 15                   calories            damaged_card
# 16           schedule_meeting                gas_type
# 17               next_holiday           change_volume
# 18        accept_reservations            order_status
# 19                  what_song      international_fees
# 20               report_fraud  measurement_conversion
# 21                    weather                   taxes
# 22         international_visa                vaccines
# 23                   greeting          reset_settings
# 24        credit_limit_change   what_are_your_hobbies
# 25               bill_balance          share_location
# 26              are_you_a_bot                     gas
# 27                  tell_joke          change_ai_name
# 28            meal_suggestion                  recipe
# 29               order_checks           card_declined

# %%
df.sample(10)
# Out:
#       datatype                                              query  \
# 12231    train    how long will i wait for a table at red lobster
# 5690     train   please confirm my reservation for may 9th at 4pm
# 3061     train  how would you say can i borrow five dollars in...
# 21254     test           tell me what the weather is looking like
# 8840     train                                what is 78 times 85
# 5029     train     remind me to buy bread next time i go shopping
# 8224     train                   how much air remains in my tires
# 3940     train    what are the best ways to build my credit score
# 5043     train  i need for you to get bananas added to my shop...
# 17364    train           i really want an italian meal suggestion
#
#                      intent  intent_idx
# 12231              how_busy          92
# 5690    confirm_reservation          26
# 3061              translate           0
# 21254               weather         108
# 8840             calculator          58
# 5029   shopping_list_update          20
# 8224          tire_pressure          52
# 3940   improve_credit_score           9
# 5043   shopping_list_update          20
# 17364       meal_suggestion         143

# %% [markdown]
# ### Distribution of query lengths

# %%
(df
 .intent
 .apply(lambda x: len(x))
 .pipe(sns.distplot)
)

# %%
(df
 .intent
 .apply(lambda x: len(x))
 .max()
)
# Out:
# 25
